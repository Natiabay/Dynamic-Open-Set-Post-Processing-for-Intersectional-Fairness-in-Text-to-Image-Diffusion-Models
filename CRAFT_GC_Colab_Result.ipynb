# %% [markdown]
# # CRAFT-GC: Stage B GPU Experiments (Google Colab)
#
# Run on **Colab GPU** (Runtime → Change runtime type → T4 GPU).
#
# 1. Upload `Research` folder as zip to `/content/Research`
# 2. Add `HF_TOKEN` in Colab Secrets (never paste tokens in cells)
# 3. Run all cells
# 4. Download `results/` and `craft-gc-paper/figures/`

# %%
# !pip install -q torch torchvision open-clip-torch diffusers transformers accelerate pandas matplotlib seaborn huggingface_hub

import os, sys, subprocess
from getpass import getpass

if not os.environ.get("HF_TOKEN"):
    try:
        from google.colab import userdata
        os.environ["HF_TOKEN"] = userdata.get("HF_TOKEN")
    except Exception:
        os.environ["HF_TOKEN"] = getpass("HF Token: ")

from huggingface_hub import login
login(token=os.environ["HF_TOKEN"])

REPO_URL = "https://github.com/Natiabay/Dynamic-Open-Set-Post-Processing-for-Intersectional-Fairness-in-Text-to-Image-Diffusion-Models.git"
PROJECT = "/content/Research"

if not os.path.isdir(PROJECT):
    subprocess.run(["git", "clone", REPO_URL, PROJECT], check=True)

os.chdir(PROJECT)
sys.path.insert(0, PROJECT)
print("CWD:", os.getcwd())
# Out:
# Note: Environment variable`HF_TOKEN` is set and is the current active token independently from the token you've just configured.
# WARNING:huggingface_hub._login:Note: Environment variable`HF_TOKEN` is set and is the current active token independently from the token you've just configured.
# CWD: /content/Research

# %%
# !python scripts/evaluate_embeddings.py --device cuda
# !python scripts/merge_paper_results.py
# !python scripts/plot_figures.py
# Out:
# Wrote 500 prompts to /content/Research/craft_gc/benchmark/prompts
# open_clip_model.safetensors: 100% 605M/605M [00:03<00:00, 193MB/s]
# /usr/local/lib/python3.12/dist-packages/open_clip/factory.py:450: UserWarning: QuickGELU mismatch between final model config (quick_gelu=False) and pretrained tag 'openai' (quick_gelu=True).
#   warnings.warn(
#                 cofs             cfs
#                 mean     std    mean     std
# method
# base          0.9971  0.0010  0.0000  0.0000
# craftgc_e     0.9971  0.0010 -0.0021  0.0030
# fairimagen_e  0.9971  0.0010 -0.0015  0.0025
# prompt_aug    0.9974  0.0008  0.0000  0.0000
# Saved results/embedding_eval.csv and results/embedding_summary.json
# {
#   "evaluation_type": "clip_embedding",
#   "main_table": [
#     {
#       "method_key": "base",
#       "method": "Base",
#       "cofs": 0.9971,
#       "cofs_std": 0.001,
#       "cfs": 0.0,
#       "cfs_std": 0.0,
#       "n": 500
#     },
#     {
#       "method_key": "prompt_aug",
# ...

# %%
# !python scripts/run_pilot_images.py --device cuda --limit 50 \
  --seeds 42 123 456 789 1024 --methods base prompt_aug fairimagen craftgc
# !python scripts/evaluate_images.py --device cuda
# !python scripts/make_qualitative_grid.py
print('Download results/ and craft-gc-paper/figures/')
# Out:
# Missing deps. Install: pip install torch diffusers open-clip-torch transformers accelerate
# Traceback (most recent call last):
#   File "/content/Research/scripts/evaluate_images.py", line 86, in <module>
#     main()
#   File "/content/Research/scripts/evaluate_images.py", line 47, in main
#     manifest = json.loads(Path(args.manifest).read_text())
#                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/pathlib.py", line 1027, in read_text
#     with self.open(mode='r', encoding=encoding, errors=errors) as f:
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/pathlib.py", line 1013, in open
#     return io.open(self, mode, buffering, encoding, errors, newline)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# FileNotFoundError: [Errno 2] No such file or directory: 'results/pilot_images/manifest.json'
# ...
